# %%
import pandas as pd
import requests
from PyQt6.QtWidgets.QGestureEvent import ignore

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
df = pd.DataFrame()

# %%
for i in range(1, 10):
    response = requests.get(
        f"https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}"
    )

    temp_df = pd.DataFrame(response.json()["results"])[
        ['id', 'title', 'overview', 'release_date',
         'popularity', 'vote_average', 'vote_count']
    ]

    df = pd.concat([df, temp_df], ignore_index=True)

df.head()
# Out:
#         id                     title  \
# 0  1632181       Accidental Partners
# 1  1007757                   Swapped
# 2      278  The Shawshank Redemption
# 3   936075                   Michael
# 4      238             The Godfather
#
#                                             overview release_date  popularity  \
# 0  Two women discover they were both scammed by t...   2026-03-12     32.4485
# 1  A small woodland creature and a majestic bird,...   2026-05-01     68.1406
# 2  Imprisoned in the 1940s for the double murder ...   1994-09-23     83.1410
# 3  The story of Michael Jackson, one of the most ...   2026-04-22    125.8724
# 4  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     38.2677
#
#    vote_average  vote_count
# 0         9.019         317
# 1         8.910        1983
# 2         8.726       30820
# 3         8.699        3647
# 4         8.687       23196

# %%
df.shape
# Out:
# (180, 7)

# %%
# This was for practice -  to proceed I will Directly import data from github,
url = "https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day17-api-to-dataframe/movies.csv"

df = pd.read_csv(url)

# %%
df.shape
# Out:
# (8551, 8)

# %%
# rapidapi
