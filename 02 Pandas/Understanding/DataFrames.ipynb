# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Creating Dataframe

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(data)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

df2 = pd.DataFrame(data_list)
columns = ["Name", "Age", "City", "Salary"]
df2 = pd.DataFrame(data_list, columns = columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2["Derignation"] = ["Doc","eng","DS","Doc"]

# %%
df2
# Out:
#     Name  Age      City  Salary Derignation
# 0   John   28  New York   65000         Doc
# 1   Anna   34     Paris   70000         eng
# 2  Peter   29    Berlin   62000          DS
# 3  Linda   42    London   85000         Doc

# %%
df2.drop('Derignation', axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary Derignation
# 0   John   28  New York   65000         Doc
# 1   Anna   34     Paris   70000         eng
# 2  Peter   29    Berlin   62000          DS
# 3  Linda   42    London   85000         Doc

# %%
df2.drop(0)
# Out:
#     Name  Age    City  Salary Derignation
# 1   Anna   34   Paris   70000         eng
# 2  Peter   29  Berlin   62000          DS
# 3  Linda   42  London   85000         Doc

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary Derignation
# 0  John   28  New York   65000         Doc
# 1  Anna   34     Paris   70000         eng

# %%
df2.iloc[1]
# Out:
# Name            Anna
# Age               34
# City           Paris
# Salary         70000
# Derignation      eng
# Name: 1, dtype: object

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %% [markdown]
# Conditional

# %%
#I only want to see those whoes age is above 30

df2[df2["Age"] > 30]
# Out:
#     Name  Age    City  Salary Derignation
# 1   Anna   34   Paris   70000         eng
# 3  Linda   42  London   85000         Doc

# %%
df2[(df2["Age"] > 30) & (df2["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary Derignation
# 1  Anna   34  Paris   70000         eng
